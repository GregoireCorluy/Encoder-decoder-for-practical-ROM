# %%
from EncoderDecoder.utils import loadData
import matplotlib.pyplot as plt
import logging
logging.disable(logging.CRITICAL)
# Out:
# WARNING:tensorflow:From c:\Users\Admin\Documents\PhD-ULB\Programming\venvPV\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From c:\Users\Admin\Documents\PhD-ULB\Programming\venvPV\lib\site-packages\PCAfold\reconstruction.py:27: The name tf.disable_eager_execution is deprecated. Please use tf.compat.v1.disable_eager_execution instead.

# %%
import os

#add the root directory
os.chdir('../')

# %%
path_data = "data-files/"
filename = "Tr35aTestFlameletNewLib_RMSprop_250_noLog_s0-AE-date_02Jun2026-hour_13h54_Xu-flamelet"

loader = loadData(filename)

training, validation = loader.loadCurves()

# %%
plt.plot(training)
plt.plot(validation)
plt.yscale("log")
plt.xlabel("Epochs", fontsize = 18)
plt.ylabel("MSE", fontsize = 18)
plt.show()

# %%
extraVars, PV, PVsource = loader.getManifoldParameters(path_data, "flamelet")
# Out:
# C:\Users\Admin\Documents\PhD-ULB\Programming\EncoderDecoder\src\EncoderDecoder\models.py:214: UserWarning: No extra manifold variable is not available because 'self.extra_manifold_variables' is empty.
#   warnings.warn("No extra manifold variable is not available because 'self.extra_manifold_variables' is empty.", UserWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 extraVars, PV, PVsource = loader.getManifoldParameters(path_data, "flamelet")
#
# File ~\Documents\PhD-ULB\Programming\EncoderDecoder\src\EncoderDecoder\utils.py:136, in loadData.getManifoldParameters(self, path_data, dataset_type)
#     132 input, output = self.getInputOutput(path_data, dataset_type)
#     134 model = self.loadModel(self.filename + "_model.pth")
# --> 136 extraVars, PV, PVsource = model.get_extraVar_PV_PVsource(input, output)
# ...
